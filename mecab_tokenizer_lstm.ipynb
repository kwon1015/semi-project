# %%
# Colab에 Mecab 설치
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# %cd Mecab-ko-for-Google-Colab
# !bash install_mecab-ko_on_colab190912.sh
# Out:
# Cloning into 'Mecab-ko-for-Google-Colab'...
# remote: Enumerating objects: 115, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 115 (delta 11), reused 10 (delta 3), pack-reused 91
# Receiving objects: 100% (115/115), 1.27 MiB | 9.43 MiB/s, done.
# Resolving deltas: 100% (50/50), done.
# /content/Mecab-ko-for-Google-Colab
# Installing konlpy.....
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 19.4 MB 1.7 MB/s
# ...
#      |████████████████████████████████| 453 kB 10.4 MB/s
# ...
# Done
# Installing mecab-0.996-ko-0.9.2.tar.gz.....
# ...
# from https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# --2022-08-12 11:24:11--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# ...

# %%
import re

# %%
# !curl -s https://raw.githubusercontent.com/teddylee777/machine-learning/master/99-Misc/01-Colab/mecab-colab.sh | bash
# Out:
# --2022-08-18 00:15:13--  https://www.dropbox.com/s/9xls0tgtf3edgns/mecab-0.996-ko-0.9.2.tar.gz?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/9xls0tgtf3edgns/mecab-0.996-ko-0.9.2.tar.gz [following]
# --2022-08-18 00:15:13--  https://www.dropbox.com/s/dl/9xls0tgtf3edgns/mecab-0.996-ko-0.9.2.tar.gz
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc436c82fd7e7f511d6e8710417f.dl.dropboxusercontent.com/cd/0/get/BrOVbEWKlCTn0SmKZ1rF8BQFgaBHSWAQWPWmXBZ1CXXgTeO0rRfox9gXHt4hZeH8fHs6YcU9X7DY8bNYDzX16P18WHGnVl44F_ttooz_q2BrzKiSdii-HFCrjjacAFYqY5gQGevVYqdgknGK_2ba8ukeSaXHtiFv_Qm7ABaSDVa_QsGK781XUUQw8Fd7JUJAa4Q/file?dl=1# [following]
# ...

# %%
import pandas as pd
import numpy as np
mecab_text = pd.read_csv('/content/twitter8000.csv')

# %%
mecab_text
# Out:
#       Unnamed: 0  Unnamed: 0.1  \
# 0              0             0
# 1              1             1
# 2              2             2
# 3              3             3
# 4              4             4
# ...          ...           ...
# 7995        7995          7995
# 7996        7996          7996
# 7997        7997          7997
# 7998        7998          7998
# 7999        7999          7999
#
#                                                    Text
# 0     RT @kimmidolmom: 우리집 강아지도 애기때 자꾸 혀를 내밀어서... 충치...
# 1     서울 되련님들도 뭣같고 오세이돈도 뭣같고 지옥런한 새끼도 뭣같고 산불 안보러간다고 ...
# 2     @EBONITE_TOORU 이쪽도 지형이 좀 높아서 침수도 잘 안 되고.... 눈도...
# 3     RT @virtual_witness: 진짜 살다살다 '재난 상황을 어떻게 복구하고 ...
# 4     여러분 대구 날씨 어떤가요? 여기 걍 하늘 뚫린 거 같은데 밑에 지방은 폭염주의보라...
# ...                                                 ...
# 7995  RT @terra_firma7: 폭우가 쏟아져 강남역 일대가 물바다가 된 1시간 3...
# 7996  RT @anna12285: @babylion0505 @free351 지겹게 이어지던...
# 7997  RT @dangerousshop: "장마 '패턴'도 '폭우→폭염→폭우'가 반복되는 ...
# ...

# %%
mecab_text= mecab_text[['Text']]

# %%
mecab_text
# Out:
#                                                    Text
# 0     RT @kimmidolmom: 우리집 강아지도 애기때 자꾸 혀를 내밀어서... 충치...
# 1     서울 되련님들도 뭣같고 오세이돈도 뭣같고 지옥런한 새끼도 뭣같고 산불 안보러간다고 ...
# 2     @EBONITE_TOORU 이쪽도 지형이 좀 높아서 침수도 잘 안 되고.... 눈도...
# 3     RT @virtual_witness: 진짜 살다살다 '재난 상황을 어떻게 복구하고 ...
# 4     여러분 대구 날씨 어떤가요? 여기 걍 하늘 뚫린 거 같은데 밑에 지방은 폭염주의보라...
# ...                                                 ...
# 7995  RT @terra_firma7: 폭우가 쏟아져 강남역 일대가 물바다가 된 1시간 3...
# 7996  RT @anna12285: @babylion0505 @free351 지겹게 이어지던...
# 7997  RT @dangerousshop: "장마 '패턴'도 '폭우→폭염→폭우'가 반복되는 ...
# 7998  RT @0cha_jj: 트위터에서 보고 '진짜 게으른 사람이 쓴 게으름 탈출법' 이...
# 7999  RT @GoodFastGo: 19년 속초 산불 때 속초시장이 전날 제주도여행을 떠났...
#
# [8000 rows x 1 columns]

# %%
# '한글'을 제외한 다른 문자 모두 제거
import re  
remove_except_ko = re.compile(r"[^가-힣ㄱ-ㅎㅏ-ㅣ\\s]") 
def preprocess(text):
    text = re.sub(remove_except_ko,' ',text).strip()
    return text 
mecab_text['Text'] = mecab_text['Text'].map(lambda x : preprocess(x))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
mecab_text
# Out:
#                                                    Text
# 0     우리집 강아지도 애기때 자꾸 혀를 내밀어서    충치나 구강구조에 문제가 있으면 혀...
# 1     서울 되련님들도 뭣같고 오세이돈도 뭣같고 지옥런한 새끼도 뭣같고 산불 안보러간다고 ...
# 2     이쪽도 지형이 좀 높아서 침수도 잘 안 되고     눈도 잘 안 오고     여름에...
# 3     ss  진짜 살다살다  재난 상황을 어떻게 복구하고 다음 재난을 어떻게 대비할지 에...
# 4     여러분 대구 날씨 어떤가요  여기 걍 하늘 뚫린 거 같은데 밑에 지방은 폭염주의보라...
# ...                                                 ...
# 7995  폭우가 쏟아져 강남역 일대가 물바다가 된  시간   분 사이에  명이 실종되었는데 ...
# 7996                             지겹게 이어지던 산불  기억속에 가득하다
# 7997  ss      장마  패턴 도  폭우 폭염 폭우 가 반복되는 형태로 최근 수년 사이...
# 7998  트위터에서 보고  진짜 게으른 사람이 쓴 게으름 탈출법  이 책을 읽었는데 저자분 ...
# 7999  s       년 속초 산불 때 속초시장이 전날 제주도여행을 떠났다가 당일 밤비행기...
#
# [8000 rows x 1 columns]

# %%
# !pip install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from konlpy.tag import Okt
okt=Okt()
# mecab 사용해 토큰화, 한글자 제거, stop_word 제거
stop_word = ['께서','에서','이다','에게','으로','이랑','까지','부터','하다']
stopPos = ['Determiner','Adverb','Conjuctions','Josa','PreEomi','Eomi','Suffix',
          'Punctuation','Foreign','Alpha','Number','Unknown','KoreanParticle']
def token_okt(text):
    text = okt.pos(text)
    text = [i for i in text if len(i[0])>1]
    text = [i for i in text if i[0] not in stop_word]
    text = [i[0] for i in text if i[1] not in stopPos]
    return text

# %%
def make_tokens(df):
    df['tokens'] = ''
    tokens_list=[]
    for i, row in df.iterrows():
        if i%500==0:
            print(i,'/',len(df))
        token = token_okt(df['Text'][i])
        df['tokens'][i] = ' '.join(token)
    return df

mecab_text = make_tokens(mecab_text)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 0 / 8000
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 500 / 8000
# 1000 / 8000
# 1500 / 8000
# 2000 / 8000
# 2500 / 8000
# 3000 / 8000
# 3500 / 8000
# 4000 / 8000
# 4500 / 8000
# 5000 / 8000
# 5500 / 8000
# 6000 / 8000
# 6500 / 8000
# 7000 / 8000
# 7500 / 8000

# %%
mecab_text
# Out:
#                                                    Text  \
# 0     우리집 강아지도 애기때 자꾸 혀를 내밀어서    충치나 구강구조에 문제가 있으면 혀...
# 1     서울 되련님들도 뭣같고 오세이돈도 뭣같고 지옥런한 새끼도 뭣같고 산불 안보러간다고 ...
# 2     이쪽도 지형이 좀 높아서 침수도 잘 안 되고     눈도 잘 안 오고     여름에...
# 3     ss  진짜 살다살다  재난 상황을 어떻게 복구하고 다음 재난을 어떻게 대비할지 에...
# 4     여러분 대구 날씨 어떤가요  여기 걍 하늘 뚫린 거 같은데 밑에 지방은 폭염주의보라...
# ...                                                 ...
# 7995  폭우가 쏟아져 강남역 일대가 물바다가 된  시간   분 사이에  명이 실종되었는데 ...
# 7996                             지겹게 이어지던 산불  기억속에 가득하다
# 7997  ss      장마  패턴 도  폭우 폭염 폭우 가 반복되는 형태로 최근 수년 사이...
# 7998  트위터에서 보고  진짜 게으른 사람이 쓴 게으름 탈출법  이 책을 읽었는데 저자분 ...
# 7999  s       년 속초 산불 때 속초시장이 전날 제주도여행을 떠났다가 당일 밤비행기...
#
#                                                  tokens
# 0     우리 강아지 애기 자꾸 내밀어서 충치 구강 구조 문제 있으면 밀고 있는대서 덜덜 떨...
# 1     서울 되련 뭣같 이돈 뭣같 지옥런 새끼 뭣같 산불 보러 간다 했으면서 멀쩡한 컨트롤...
# 2                              지형 높아서 침수 되고 오고 여름 덥고 하아
# 3     진짜 살다 살다 재난 상황 어떻게 복구 다음 재난 어떻게 대비 할지 대한 뉴스 아니...
# ...

# %%
# 빈칸 찾아내기
mecab_text.replace('', np.nan, inplace=True)
mecab_text.isnull().sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,
# Text      0
# tokens    0
# dtype: int64

# %%
#Null 값 없애기
mecab_text=mecab_text.dropna()
mecab_text.isnull().sum()
# Out:
# Text      0
# tokens    0
# dtype: int64

# %%
mecab_text
# Out:
#                                                    Text  \
# 0     우리집 강아지도 애기때 자꾸 혀를 내밀어서    충치나 구강구조에 문제가 있으면 혀...
# 1     서울 되련님들도 뭣같고 오세이돈도 뭣같고 지옥런한 새끼도 뭣같고 산불 안보러간다고 ...
# 2     이쪽도 지형이 좀 높아서 침수도 잘 안 되고     눈도 잘 안 오고     여름에...
# 3     ss  진짜 살다살다  재난 상황을 어떻게 복구하고 다음 재난을 어떻게 대비할지 에...
# 4     여러분 대구 날씨 어떤가요  여기 걍 하늘 뚫린 거 같은데 밑에 지방은 폭염주의보라...
# ...                                                 ...
# 7995  폭우가 쏟아져 강남역 일대가 물바다가 된  시간   분 사이에  명이 실종되었는데 ...
# 7996                             지겹게 이어지던 산불  기억속에 가득하다
# 7997  ss      장마  패턴 도  폭우 폭염 폭우 가 반복되는 형태로 최근 수년 사이...
# 7998  트위터에서 보고  진짜 게으른 사람이 쓴 게으름 탈출법  이 책을 읽었는데 저자분 ...
# 7999  s       년 속초 산불 때 속초시장이 전날 제주도여행을 떠났다가 당일 밤비행기...
#
#                                                  tokens
# 0     우리 강아지 애기 자꾸 내밀어서 충치 구강 구조 문제 있으면 밀고 있는대서 덜덜 떨...
# 1     서울 되련 뭣같 이돈 뭣같 지옥런 새끼 뭣같 산불 보러 간다 했으면서 멀쩡한 컨트롤...
# 2                              지형 높아서 침수 되고 오고 여름 덥고 하아
# 3     진짜 살다 살다 재난 상황 어떻게 복구 다음 재난 어떻게 대비 할지 대한 뉴스 아니...
# ...

# %%
mecab1=mecab_text[['tokens']]

# %%
mecab1
# Out:
#                                                  tokens
# 0     우리 강아지 애기 자꾸 내밀어서 충치 구강 구조 문제 있으면 밀고 있는대서 덜덜 떨...
# 1     서울 되련 뭣같 이돈 뭣같 지옥런 새끼 뭣같 산불 보러 간다 했으면서 멀쩡한 컨트롤...
# 2                              지형 높아서 침수 되고 오고 여름 덥고 하아
# 3     진짜 살다 살다 재난 상황 어떻게 복구 다음 재난 어떻게 대비 할지 대한 뉴스 아니...
# 4       여러분 대구 날씨 어떤 가요 여기 하늘 뚫린 같은데 지방 폭염 주의보 믿기지가 않어요
# ...                                                 ...
# 7995  폭우 쏟아져 강남역 일대 물바다 시간 사이 실종 되었는데 뚜껑 폭발 열린 한강 이어...
# 7996                                   지겹게 이어지던 산불 가득하다
# 7997  장마 패턴 폭우 폭염 폭우 반복 되는 형태 최근 수년 사이 과거 달라졌다 온난화 대...
# 7998  트위터 보고 진짜 게으른 사람 게으름 탈출 읽었는데 저자 얘기 공감 된다 현실 직면...
# 7999  속초 산불 속초시 전날 제주도 여행 떠났다가 당일 비행기 없어 다음 비행기 부랴부랴...
#
# [8000 rows x 1 columns]

# %%
pos_dict = pd.DataFrame(pd.read_csv(r'/content/pos_pol_word_단어추가.txt', sep='\n', quoting=3,header=15))
pos_dict.rename(columns={'극성 : 긍정':'word'},inplace=True)
pos_dict.head()
# Out:
#     word
# 0    멀쩡한
# 1   가득하다
# 2    그리워
# 3  바람직하지
# 4     깔깔

# %%
neg_dict = pd.DataFrame(pd.read_csv(r'/content/neg_pol_word_단어추가.txt', sep='\n', quoting=3,header=14))
neg_dict.rename(columns={'극성 : 부정':'word'},inplace=True)
neg_dict.head()
# Out:
#   word
# 0  지옥런
# 1   새끼
# 2   산불
# 3  버리고
# 4   침수

# %%
bad_dict = pd.DataFrame(pd.read_csv(r'/content/욕설 사전.txt',sep='\n',quoting=3,header=None))
bad_dict.rename(columns={0:'word'},inplace=True)
bad_dict.head()
# Out:
#   word
# 0  뭣같음
# 1   지랄
# 2   개뿔
# 3   슈펄
# 4  디질것

# %%
tone_ls = []
for doc in mecab1['tokens']:
    #print(doc.split())
    #words=[]
    #words.append(doc.split(' '))
    splitdoc = doc.split()
    pos=0
    neg=0
    bad=1
    for word in splitdoc:
        if word in list(pos_dict['word']):
            pos += 1
        if word in list(neg_dict['word']):
            neg += 1
        if word in list(bad_dict['word']):
            bad = 0
    if bad == 0 :
        tone_ls.append(-3)            
    elif (pos+neg)!=0:
        tone = (pos-neg)/(pos+neg)
        if tone >0:
          
          tone_ls.append(1)
        elif (tone <0) & (tone >=-0.5) :
          
          tone_ls.append(-1)
        elif tone< -0.5:
          tone_ls.append(-2)  
        elif tone ==0:
          tone_ls.append(0)
    else:
        tone_ls.append(0)
mecab1['tone']= tone_ls

# %%
mecab1
# Out:
#                                                  tokens  tone
# 0     우리 강아지 애기 자꾸 내밀어서 충치 구강 구조 문제 있으면 밀고 있는대서 덜덜 떨...     0
# 1     서울 되련 뭣같 이돈 뭣같 지옥런 새끼 뭣같 산불 보러 간다 했으면서 멀쩡한 컨트롤...    -3
# 2                              지형 높아서 침수 되고 오고 여름 덥고 하아    -2
# 3     진짜 살다 살다 재난 상황 어떻게 복구 다음 재난 어떻게 대비 할지 대한 뉴스 아니...     0
# 4       여러분 대구 날씨 어떤 가요 여기 하늘 뚫린 같은데 지방 폭염 주의보 믿기지가 않어요    -2
# ...                                                 ...   ...
# 7995  폭우 쏟아져 강남역 일대 물바다 시간 사이 실종 되었는데 뚜껑 폭발 열린 한강 이어...    -2
# 7996                                   지겹게 이어지던 산불 가득하다    -1
# 7997  장마 패턴 폭우 폭염 폭우 반복 되는 형태 최근 수년 사이 과거 달라졌다 온난화 대...    -2
# 7998  트위터 보고 진짜 게으른 사람 게으름 탈출 읽었는데 저자 얘기 공감 된다 현실 직면...     0
# 7999  속초 산불 속초시 전날 제주도 여행 떠났다가 당일 비행기 없어 다음 비행기 부랴부랴...    -2
#
# [8000 rows x 2 columns]

# %%
# mecab_text.to_csv('데이터수집본re.csv', encoding="utf8")

# %%
import konlpy

# %%
from tqdm import tqdm
from konlpy.tag import Mecab

# %%
# 형태소 분석기 Mecab을 사용하여 토큰화를 진행해보겠습니다.
mecab = Mecab()

# %%
# # output_file에는 총 몇 줄이 있는지 확인합니다.
# f = open('/content/데이터수집본re.csv', encoding="utf8")
# lines = f.read().splitlines()
# print(len(lines))

# %%
# 95,461개의 줄이 존재합니다. 상위 10개만 출력해봅시다.

# %%
# lines[:10]

# %%
result = []

for line in tqdm(mecab1['tokens']):
  # 빈 문자열이 아닌 경우에만 수행
  if line:
    result.append(mecab.morphs(line))
# Out:
# 100%|██████████| 8000/8000 [00:01<00:00, 5775.77it/s]

# %%
# 빈 문자열은 제외하고 형태소 분석을 진행했습니다. 
# 이제 몇 개의 줄. 즉, 몇 개의 문장이 존재하는지 확인해봅시다.

# %%
len(result)
# Out:
# 8000

# %%
# 95,461개로 문장의 수가 줄지 않았습니다.

# %%
result
# Out:
# [['우리',
#   '강아지',
#   '애기',
#   '자꾸',
#   '내밀',
#   '어서',
#   '충치',
#   '구강',
#   '구조',
#   '문제',
#   '있',
#   '으면',
#   '밀',
#   '고',
#   '있',
#   '는대서',
#   '덜덜',
#   '떨',
#   '면서',
#   '병원',
#   '갔',
#   '는데',
#   '그냥',
#   '길',
#   '대',
#   '길',
#   '어서',
#   '가끔',
#   '아니',
#   '고',
#   '자주',
#   '넣',
#   '는',
#   '거래',
#   '애기',
#   '꾸준히'],
#  ['서울',
#   '되',
#   '련',
#   '뭣',
#   '같',
#   '이',
#   '돈',
#   '뭣',
#   '같',
#   '지옥',
#   '런',
#   '새끼',
#   '뭣',
#   '같',
#   '산불',
#   '보',
#   '러',
#   '간다',
#   '했',
#   '으면서',
#   '멀쩡',
#   '한',
#   '컨트롤',
#   '타워',
#   '버리',
#   '고',
#   '침수',
#   '궁',
#   '댕',
#   '뭉개',
#   '있',
#   '던',
#   '새끼',
#   '뭣',
#   '같',
#   '음'],
#  ['지형', '높', '아서', '침수', '되', '고', '오', '고', '여름', '덥', '고', '하', '아'],
#  ['진짜',
#   '살',
#   '다',
#   '살',
#   '다',
#   '재난',
#   '상황',
#   '어떻게',
#   '복구',
#   '다음',
#   '재난',
#   '어떻게',
#   '대비',
#   '할지',
#   '대한',
#   '뉴스',
#   '아니',
#   '라',
#   '재난',
#   '상황',
#   '대처',
#   '하',
#   '느라',
# ...

# %%
type(result)
# Out:
# list

# %%
mecab1['word']=pd.Series(result)

# %%
mecab1
# Out:
#                                                  tokens  tone  \
# 0     우리 강아지 애기 자꾸 내밀어서 충치 구강 구조 문제 있으면 밀고 있는대서 덜덜 떨...     0
# 1     서울 되련 뭣같 이돈 뭣같 지옥런 새끼 뭣같 산불 보러 간다 했으면서 멀쩡한 컨트롤...    -3
# 2                              지형 높아서 침수 되고 오고 여름 덥고 하아    -2
# 3     진짜 살다 살다 재난 상황 어떻게 복구 다음 재난 어떻게 대비 할지 대한 뉴스 아니...     0
# 4       여러분 대구 날씨 어떤 가요 여기 하늘 뚫린 같은데 지방 폭염 주의보 믿기지가 않어요    -2
# ...                                                 ...   ...
# 7995  폭우 쏟아져 강남역 일대 물바다 시간 사이 실종 되었는데 뚜껑 폭발 열린 한강 이어...    -2
# 7996                                   지겹게 이어지던 산불 가득하다    -1
# 7997  장마 패턴 폭우 폭염 폭우 반복 되는 형태 최근 수년 사이 과거 달라졌다 온난화 대...    -2
# 7998  트위터 보고 진짜 게으른 사람 게으름 탈출 읽었는데 저자 얘기 공감 된다 현실 직면...     0
# 7999  속초 산불 속초시 전날 제주도 여행 떠났다가 당일 비행기 없어 다음 비행기 부랴부랴...    -2
#
#                                                    word
# 0     [우리, 강아지, 애기, 자꾸, 내밀, 어서, 충치, 구강, 구조, 문제, 있, 으...
# 1     [서울, 되, 련, 뭣, 같, 이, 돈, 뭣, 같, 지옥, 런, 새끼, 뭣, 같, ...
# ...

# %%
import konlpy

# %% [markdown]
# Word2Vec 학습

# %%
# from gensim.models import Word2Vec
# w2v_model = Word2Vec(mecab1['word'], size=100, window=5, min_count=5, workers=4, sg=0)
# Out:
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay

# %%
# w2v_model.train(mecab1['word'],epochs=10,total_examples=len(mecab1['word']))
# Out:
# WARNING:gensim.models.base_any2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# (91162, 188150)

# %%
# w2v_model.wv.get_vector('폭염')
# Out:
# array([-0.0471651 , -0.48604834, -0.05126873,  0.17372158,  0.17117384,
#         0.07252903, -0.19358446,  0.03208101,  0.3518953 , -0.13845585,
#        -0.11806884,  0.30697307,  0.19527267,  0.23898914,  0.15249035,
#        -0.11940234, -0.06275327, -0.00157507, -0.19533557, -0.06219251,
#         0.1318571 , -0.28471053,  0.40438268,  0.09621154,  0.21935545,
#         0.19172016, -0.04801303,  0.06292937,  0.05988831, -0.06635524,
#        -0.2688427 ,  0.2699307 ,  0.01784352,  0.05365425,  0.33597127,
#        -0.49360666,  0.24822691, -0.06267721, -0.35758102, -0.35257638,
#         0.15622115,  0.03433609,  0.23848012, -0.04041442,  0.13771227,
#        -0.04950699, -0.00985904, -0.24400821,  0.02808829,  0.36036164,
#        -0.19246225, -0.19653617, -0.36096132,  0.12670906,  0.08062725,
#        -0.4516243 , -0.7960447 , -0.3182171 , -0.15253486,  0.04098013,
#         0.30076182, -0.17280638, -0.1440175 ,  0.26840797,  0.05067078,
# ...

# %%
# vocab=w2v_model.wv.vocab

# %%
# w2v_model.wv.most_similar('폭염')
# Out:
# [('주의보', 0.9995733499526978),
#  ('경보', 0.999366283416748),
#  ('호우', 0.9993630647659302),
#  ('폭우', 0.9991953372955322),
#  ('발령', 0.9991815686225891),
#  ('발효', 0.9991775751113892),
#  ('산사태', 0.9991214275360107),
#  ('서울', 0.99900221824646),
#  ('피해', 0.9989963173866272),
#  ('남부', 0.9989914298057556)]

# %%
# w2v_model.wv.similarity('폭염','경보')
# Out:
# 0.99936634

# %%
# vocab=list(vocab.keys())

# %%
# word_vec_dict={}
# for word in vocab:
#   word_vec_dict[word]=w2v_model.wv.get_vector(word)

# %%
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(mecab1['word'])
encoded = tokenizer.texts_to_sequences(mecab1['word'])

# %%
encoded
# Out:
# [[84,
#   1869,
#   1533,
#   1803,
#   2624,
#   113,
#   2625,
#   2626,
#   147,
#   201,
#   4,
#   114,
#   484,
#   3,
#   4,
#   2627,
#   2628,
#   853,
#   98,
#   436,
#   308,
#   13,
#   359,
#   214,
#   109,
#   214,
#   113,
#   1735,
#   53,
#   3,
#   1142,
#   542,
#   2,
#   2443,
#   1533,
#   2629],
#  [22,
#   9,
#   854,
#   247,
#   30,
#   24,
#   609,
#   247,
#   30,
#   930,
#   282,
#   186,
#   247,
#   30,
#   23,
#   31,
#   290,
#   449,
#   7,
#   198,
#   363,
#   25,
#   736,
#   855,
#   679,
#   3,
#   6,
#   948,
#   949,
#   856,
#   4,
#   16,
#   186,
#   247,
#   30,
#   41],
#  [2630, 1278, 329, 6, 9, 3, 104, 3, 248, 2320, 3, 1, 74],
#  [61,
#   168,
#   10,
#   168,
#   10,
#   37,
#   40,
#   374,
#   67,
#   44,
#   37,
#   374,
#   445,
#   549,
#   680,
#   32,
#   53,
#   375,
#   37,
#   40,
#   195,
#   1,
#   765,
#   75,
#   206,
#   11,
#   70,
#   7,
#   10,
#   32,
#   190,
#   1,
#   2],
#  [156,
#   1601,
#   159,
#   204,
# ...

# %%
mecab1['word1']=pd.Series(encoded)

# %%
mecab1
# Out:
#                                                  tokens  tone  \
# 0     우리 강아지 애기 자꾸 내밀어서 충치 구강 구조 문제 있으면 밀고 있는대서 덜덜 떨...     0
# 1     서울 되련 뭣같 이돈 뭣같 지옥런 새끼 뭣같 산불 보러 간다 했으면서 멀쩡한 컨트롤...    -3
# 2                              지형 높아서 침수 되고 오고 여름 덥고 하아    -2
# 3     진짜 살다 살다 재난 상황 어떻게 복구 다음 재난 어떻게 대비 할지 대한 뉴스 아니...     0
# 4       여러분 대구 날씨 어떤 가요 여기 하늘 뚫린 같은데 지방 폭염 주의보 믿기지가 않어요    -2
# ...                                                 ...   ...
# 7995  폭우 쏟아져 강남역 일대 물바다 시간 사이 실종 되었는데 뚜껑 폭발 열린 한강 이어...    -2
# 7996                                   지겹게 이어지던 산불 가득하다    -1
# 7997  장마 패턴 폭우 폭염 폭우 반복 되는 형태 최근 수년 사이 과거 달라졌다 온난화 대...    -2
# 7998  트위터 보고 진짜 게으른 사람 게으름 탈출 읽었는데 저자 얘기 공감 된다 현실 직면...     0
# 7999  속초 산불 속초시 전날 제주도 여행 떠났다가 당일 비행기 없어 다음 비행기 부랴부랴...    -2
#
#                                                    word  \
# 0     [우리, 강아지, 애기, 자꾸, 내밀, 어서, 충치, 구강, 구조, 문제, 있, 으...
# 1     [서울, 되, 련, 뭣, 같, 이, 돈, 뭣, 같, 지옥, 런, 새끼, 뭣, 같, ...
# ...

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
X_train=mecab1.word1[:7700]
Y_train=mecab1.tone[:7700]

X_test=mecab1.word1[7700:]
Y_test=mecab1.tone[7700:]

# %%
max_len=40
X_train = pad_sequences(X_train, maxlen=max_len)
X_test = pad_sequences(X_test, maxlen=max_len)

print('X_train shape: ', X_train.shape)
print('X_test shape: ', X_test.shape)
# Out:
# X_train shape:  (7700, 40)
# X_test shape:  (300, 40)

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, LSTM, Embedding
from keras.preprocessing import sequence
from keras.utils import np_utils

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
Y_train = encoder.fit_transform(Y_train)
Y_test = encoder.fit_transform(Y_test)

# %%
X_test.shape
# Out:
# (300, 1000)

# %%
Y_test.shape
# Out:
# (300,)

# %%
X_test.ndim
# Out:
# 2

# %%
model = Sequential()
model.add(Embedding(1000,100))
model.add(LSTM(1000, activation='tanh'))
model.add(Dense(1000,activation='relu'))
model.add(Dense(500,activation='relu'))
model.add(Dense(5, activation='softmax'))

# optimizer=tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=1e-6, amsgrad=False)
optimizer=tf.keras.optimizers.SGD(learning_rate=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %%
hist=model.fit(X_train,Y_train,batch_size=100, epochs=20,validation_data=(X_test, Y_test))
# Out:
# Epoch 1/20
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# <ipython-input-86-d93e174befad> in <module>
# ----> 1 hist=model.fit(X_train,Y_train,batch_size=100, epochs=20,validation_data=(X_test, Y_test))
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ...

# %%
max_len = max(len(item) for item in encoded)
print('최대 길이 :',max_len)

# %%
tok = Tokenizer()
tok.fit_on_texts(mecab1['word'])
vocab_size = len(tok.word_index) + 1
encd_rev = tok.texts_to_sequences(mecab1['word'])

# %%
max_rev_len=55  # max lenght of a review
vocab_size = len(tok.word_index) + 1  # total no of words
embed_dim=100 # embedding dimension as choosen in word2vec constructor

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# now padding to have a amximum length of 1565
pad_rev= pad_sequences(encd_rev, maxlen=max_rev_len, padding='post')
pad_rev.shape   # note that we had 100K reviews and we have padded each review to have  a lenght of 1565 words.

# %%
embed_matrix=np.zeros(shape=(vocab_size,embed_dim))
for word,i in tok.word_index.items():
  embed_vector=word_vec_dict.get(word)
  if embed_vector is not None:  # word is in the vocabulary learned by the w2v model
    embed_matrix[i]=embed_vector
  # if word is not found then embed_vector corressponding to that vector will stay zero.

# %%
mecab1

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
Y = encoder.fit_transform(mecab1['tone'])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(pad_rev,Y,test_size=0.20,random_state=42)

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, LSTM, Embedding
from keras.preprocessing import sequence
from keras.utils import np_utils

# %%
model = Sequential()
model.add(Embedding(1000,100))
model.add(LSTM(1000, activation='tanh'))
model.add(Dense(1000,activation='relu'))
model.add(Dense(500,activation='relu'))
model.add(Dense(5, activation='softmax'))

# optimizer=tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=1e-6, amsgrad=False)
optimizer=tf.keras.optimizers.SGD(learning_rate=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %%
hist=model.fit(x_train,y_train,batch_size=100, epochs=20,validation_data=(x_test, y_test))

# %%
loss, acc = model.evaluate(x_test, y_test, batch_size=32)

print('Test loss:', loss)
print('Test accuracy:', acc)

# %%
print("\n 정확도 : %.4f" % (model.evaluate(x_test, y_test)[1]))

y_test_loss = hist.history['val_loss']
y_train_loss = hist.history['loss']

x_len = np.arange(len(y_test_loss))
plt.plot (x_len, y_test_loss, marker=',', c='red', label='Testset_loss')
plt.plot(x_len, y_train_loss, marker=',', c='blue', label='Trainset_loss')

plt.legend(loc='upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
import tensorflow as tf

# %%
# from keras.initializers import Constant
# from keras.layers import ReLU
# from keras.layers import Dropout
# model=Sequential()
# model.add(Embedding(input_dim=vocab_size,output_dim=embed_dim,input_length=max_rev_len,embeddings_initializer=Constant(embed_matrix)))
# # model.add(CuDNNLSTM(64,return_sequences=False)) # loss stucks at about 
# model.add(Flatten())
# model.add(Dense(16,activation='relu'))
# model.add(Dropout(0.50))
# # model.add(Dense(16,activation='relu'))
# # model.add(Dropout(0.20))
# model.add(Dense(5,activation='softmax'))  # sigmod for bin. classification.

# %%
# model.compile(optimizer=keras.optimizers.RMSprop(lr=1e-3),loss='binary_crossentropy',metrics=['accuracy'])

# %%
# epochs=5
# batch_size=64

# %%
# history=model.fit(x_train,y_train,epochs=epochs,batch_size=batch_size,validation_data=(x_test,y_test))

# %%
model_result1 = model.wv.most_similar('폭염')
print(model_result1)

# %%
model_result2 = model.wv.most_similar('폭우')
print(model_result2)

# %%
model_result3 = model.wv.most_similar('장마')
print(model_result3)

# %%
model_result4 = model.wv.most_similar('열대야')
print(model_result4)

# %%
model_result5 = model.wv.most_similar('미세먼지')
print(model_result5)

# %%
model_result6 = model.wv.most_similar('감사')
print(model_result6)

# %%
model_result7 = model.wv.most_similar('구호')
print(model_result7)

# %%
model_result8 = model.wv.most_similar('봉사')
print(model_result8)

# %%
# model_result9 = model.wv.most_similar('헌금')
# print(model_result9)

# # KeyError: "word '헌금' not in vocabulary"

# %%
model_result10 = model.wv.most_similar('구조')
print(model_result10)

# %%
model_result11 = model.wv.most_similar('복원')
print(model_result11)

# %%
model_result12 = model.wv.most_similar('성금')
print(model_result12)

# %%
model_result13 = model.wv.most_similar('덕분')
print(model_result13)

# %%
model_result14 = model.wv.most_similar('다행')
print(model_result14)

# %%
model_result15 = model.wv.most_similar('탈출')
print(model_result15)

# %%
model_result16 = model.wv.most_similar('자원')
print(model_result16)

# %%
model_result17 = model.wv.most_similar('지원')
print(model_result17)

# %%
model_result18 = model.wv.most_similar('참여')
print(model_result18)
